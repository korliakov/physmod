# %%
import numpy as np

data = np.loadtxt("numbers.txt").T

x = data[0]
v = data[1]
t = data[2]

# %%
import matplotlib.pyplot as plt

plt.title("x(v)")
plt.plot(v[:], x[:])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title("x(t)")
plt.plot(t, x)
plt.show()
