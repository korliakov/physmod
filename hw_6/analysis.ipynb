# %%
import numpy as np

data1 = np.loadtxt("numbers1.txt").T
data2 = np.loadtxt("numbers2.txt").T
data3 = np.loadtxt("numbers3.txt").T

x1 = data1[0]
v1 = data1[1]
t1 = data1[2]


x2 = data2[0]
v2 = data2[1]
t2 = data2[2]

x3 = data3[0]
v3 = data3[1]
t3 = data3[2]

# %%
import matplotlib.pyplot as plt



plt.figure(figsize=(8, 6), dpi=300)

plt.title("x(t)")

# plt.plot(t1[99000:99999], x1[99000:99999], color = 'red') #euler
# plt.plot(t2[99000:99999], x2[99000:99999], color = 'blue', linestyle = '-') #Heun
plt.plot(t3[99000:99999], x3[99000:99999], color = 'green') #rk
plt.plot(t3[99000:99999], np.cos(0.1*t3[99000:99999]), color = 'y', linestyle = '--') #theor
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title("x(t)")
plt.plot(t1[100:1000], x1[100:1000])
plt.plot(t2[100:1000], x2[100:1000])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title("x(v)")
plt.plot(v, x)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-77f6199c8fa0> in <module>
#       2
#       3 plt.title("x(v)")
# ----> 4 plt.plot(v, x)
#       5 plt.show()
#
# NameError: name 'v' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

E = (x*x + v*v)/2

plt.title("E(t)")
plt.plot(t, E)
plt.show()
