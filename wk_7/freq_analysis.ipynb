# %%
import numpy as np

data1 = np.loadtxt("frequency_response.txt").T

# %%
A = data1[0]
w = data1[1]

# %%
import matplotlib.pyplot as plt



plt.figure(figsize=(8, 6), dpi=100)

plt.title("A(w)")



plt.plot(w, A, color = 'green')

plt.show()

# %%
A_max, index_max = max(A), list(A).index(max(A))
w0 = w[index_max]

print(w0)
# Out:
# 0.48

# %%
A0 = A_max/(2**0.5)
